# %% [markdown]
# <a href="https://colab.research.google.com/github/plummer92/For-fun/blob/main/comfyui.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir -p /content/ComfyUI/models/clip_vision
# !mkdir -p /content/ComfyUI/models/ipadapter

# !wget -O /content/ComfyUI/models/clip_vision/clip_vision_g.safetensors \
https://huggingface.co/h94/IP-Adapter/resolve/main/models/image_encoder/model.safetensors

# !wget -O /content/ComfyUI/models/ipadapter/ipadapter_sdxl.bin \
https://huggingface.co/h94/IP-Adapter/resolve/main/sdxl_models/ip-adapter_sdxl.bin
# Out:
# --2025-12-09 18:44:16--  https://huggingface.co/h94/IP-Adapter/resolve/main/models/image_encoder/model.safetensors
# Resolving huggingface.co (huggingface.co)... 13.33.45.10, 13.33.45.68, 13.33.45.84, ...
# Connecting to huggingface.co (huggingface.co)|13.33.45.10|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# %cd /content/ComfyUI/custom_nodes
# !git clone https://github.com/ltdrdata/ComfyUI-Manager
# Out:
# /content/ComfyUI/custom_nodes
# fatal: destination path 'ComfyUI-Manager' already exists and is not an empty directory.

# %%
# !git clone https://github.com/comfyanonymous/ComfyUI.git
# %cd ComfyUI
# !pip install -r requirements.txt
# Out:
# Cloning into 'ComfyUI'...
# remote: Enumerating objects: 28368, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 28368 (delta 29), reused 12 (delta 12), pack-reused 28327 (from 5)
# Receiving objects: 100% (28368/28368), 74.98 MiB | 11.72 MiB/s, done.
# Resolving deltas: 100% (19221/19221), done.
# /content/ComfyUI/custom_nodes/ComfyUI
# ...

# %%
# %cd /content/ComfyUI/models/checkpoints
# !wget https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_base_1.0.safetensors
# Out:
# /content/ComfyUI/models/checkpoints
# --2025-12-09 18:45:01--  https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_base_1.0.safetensors
# Resolving huggingface.co (huggingface.co)... 13.33.45.68, 13.33.45.84, 13.33.45.37, ...
# Connecting to huggingface.co (huggingface.co)|13.33.45.68|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !wget -O /content/ComfyUI/models/clip_vision/clip_vision_h.safetensors \
https://huggingface.co/h94/IP-Adapter/resolve/main/models/image_encoder/model.safetensors
# Out:
# --2025-12-09 18:43:53--  https://huggingface.co/h94/IP-Adapter/resolve/main/models/image_encoder/model.safetensors
# Resolving huggingface.co (huggingface.co)... 13.33.45.37, 13.33.45.84, 13.33.45.10, ...
# Connecting to huggingface.co (huggingface.co)|13.33.45.37|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !wget https://huggingface.co/stabilityai/stable-diffusion-xl-refiner-1.0/resolve/main/sd_xl_refiner_1.0.safetensors
# Out:
# --2025-12-09 18:46:18--  https://huggingface.co/stabilityai/stable-diffusion-xl-refiner-1.0/resolve/main/sd_xl_refiner_1.0.safetensors
# Resolving huggingface.co (huggingface.co)... 13.33.45.37, 13.33.45.84, 13.33.45.10, ...
# Connecting to huggingface.co (huggingface.co)|13.33.45.37|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# %cd /content/ComfyUI/models/vae
# !wget https://huggingface.co/stabilityai/sdxl-vae/resolve/main/sdxl_vae.safetensors
# Out:
# /content/ComfyUI/models/vae
# --2025-12-09 18:47:15--  https://huggingface.co/stabilityai/sdxl-vae/resolve/main/sdxl_vae.safetensors
# Resolving huggingface.co (huggingface.co)... 13.33.45.10, 13.33.45.37, 13.33.45.68, ...
# Connecting to huggingface.co (huggingface.co)|13.33.45.10|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !mv /content/sdxl_photorealistic_slider_v1-0.safetensors /content/ComfyUI/models/loras/
# Out:
# mv: cannot stat '/content/sdxl_photorealistic_slider_v1-0.safetensors': No such file or directory

# %%
# !ls /content/ComfyUI/models/loras
# Out:
# put_loras_here	sdxl_photorealistic_slider_v1-0.safetensors

# %%
# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64
# !chmod +x cloudflared-linux-amd64

# %%
# %cd /content/ComfyUI
# !nohup python main.py --port 8188 &>/content/comfyui.log &
# Out:
# /content/ComfyUI

# %%
# !cp "/content/drive/MyDrive/comfyui-addons/juggernautXL_ragnarokBy.safetensors" /content/ComfyUI/models/checkpoints/

# %%
# !ls /content/ComfyUI/models/checkpoints | grep jugger
# Out:
# juggernautXL_ragnarokBy.safetensors

# %%
# %cd /content/ComfyUI
# !pkill -f main.py
# !nohup python main.py --port 8188 &>/content/comfyui.log &
# Out:
# /content/ComfyUI

# %%
# !/content/ComfyUI/models/vae/cloudflared-linux-amd64 tunnel --url http://localhost:8188
# Out:
# 2025-12-09T18:48:43Z INF Thank you for trying Cloudflare Tunnel. Doing so, without a Cloudflare account, is a quick way to experiment and try it out. However, be aware that these account-less Tunnels have no uptime guarantee, are subject to the Cloudflare Online Services Terms of Use (https://www.cloudflare.com/website-terms/), and Cloudflare reserves the right to investigate your use of Tunnels for violations of such terms. If you intend to use Tunnels in production you should use a pre-created named tunnel by following: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps
# 2025-12-09T18:48:43Z INF Requesting new quick Tunnel on trycloudflare.com...
# 2025-12-09T18:48:48Z INF +--------------------------------------------------------------------------------------------+
# 2025-12-09T18:48:48Z INF |  Your quick Tunnel has been created! Visit it at (it may take some time to be reachable):  |
# ...

# %%
# !/content/ComfyUI/models/vae/cloudflared-linux-amd64 tunnel --url http://localhost:8188
